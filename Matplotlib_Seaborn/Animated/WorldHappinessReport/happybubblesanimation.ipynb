# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('World Happiness Report (2005-2023).csv')
df['Country'] = pd.Categorical(df['Country'])
#TODO: Create a legend corresponding to the following:
df['Country'].unique()
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina', ..., 'Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe']
# Length: 165
# Categories (165, object): ['Afghanistan', 'Albania', 'Algeria', 'Angola', ..., 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe']

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=120)

def update(frame):
    
    year = df.loc[df.Year == frame, :]

    ax.scatter(
        x=year['Happiness Score'], 
        y=year['GDP per Capita'], 
        s=year['Life Expectancy']*60,
        c=year['Country'].cat.codes,
        cmap="Accent", 
        alpha=0.2, 
        edgecolors="white", 
        linewidths=2)

    ax.set_title(f"World Happiness in {frame}")
    ax.set_xlabel("Happiness Score")
    ax.set_ylabel("GDP per Capita")
    ax.set_yscale('log')
    ax.set_ylim(4,14)
    ax.set_xlim(2,9)

    return ax

bubbles = FuncAnimation(fig, update, frames=df['Year'].unique())
bubbles.save('happy.gif', fps=1)
