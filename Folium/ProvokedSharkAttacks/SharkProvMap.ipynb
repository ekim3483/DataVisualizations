# %%
import pandas as pd

# %%
import numpy as np

# %%
import folium

print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
from folium import plugins

# %%
df = pd.read_csv('cleaned_sharkdata2.csv')

# %%
df.fillna('Unknown')
# Out:
#      Unnamed: 0  unnamed:_0   case_number        date  year        type  \
# 0             0           0    2017.06.11  2017-06-11  2017  Unprovoked
# 1             1           1  2017.06.10.b  2017-06-10  2017  Unprovoked
# 2             2           2  2017.06.10.a  2017-06-10  2017  Unprovoked
# 3             3           3  2017.06.07.R  2017-06-07  2017  Unprovoked
# 4             4           4    2017.06.04  2017-06-04  2017  Unprovoked
# ..          ...         ...           ...         ...   ...         ...
# 493         493         495  2013.08.25.b  2013-08-25  2013  Unprovoked
# 494         494         496    2013.08.25  2013-08-25  2013  Unprovoked
# 495         495         497    2013.08.18  2013-08-18  2013  Unprovoked
# 496         496         498    2013.08.17  2013-08-17  2013  Unprovoked
# 497         497         499    2013.08.14  2013-08-14  2013  Unprovoked
#
#             country               area  \
# 0         AUSTRALIA  Western Australia
# 1         AUSTRALIA           Victoria
# 2               USA            Florida
# 3    UNITED KINGDOM        South Devon
# 4               USA            Florida
# ..              ...                ...
# 493             USA            Florida
# 494       AUSTRALIA    New South Wales
# 495             USA             Hawaii
# 496             USA         California
# 497             USA             Hawaii
#
#                                               location           activity  \
# 0                             Point Casuarina, Bunbury      Body boarding
# 1                       Flinders, Mornington Peninsula            Surfing
# 2                          Ponce Inlet, Volusia County            Surfing
# 3                                        Bantham Beach           Surfing
# 4      Middle Sambo Reef off Boca Chica, Monroe County       Spearfishing
# ..                                                 ...                ...
# 493  Winterhaven Park,           Ponce Inlet, Volus...    Boogie boarding
# 494                                             Smiths  Wrangling a shark
# 495                                           Pohoiki             Surfing
# 496      Pillar Point, Half-Moon Bay, San Mateo County            Surfing
# 497                                      Makenat, Maui         Snorkeling
#
#      ... fatal_(y/n)     time                           species_  \
# 0    ...           N    08h30                   White shark, 4 m
# 1    ...           N    15h45                       7 gill shark
# 2    ...           N    10h00                            Unknown
# 3    ...           N  Unknown  3m shark, probably a smooth hound
# 4    ...           N  Unknown                           8' shark
# ..   ...         ...      ...                                ...
# 493  ...           N    17h00                            Unknown
# 494  ...           N    15h00                            Unknown
# 495  ...           N    13h00                            Unknown
# 496  ...           N    12h40                        White shark
# 497  ...           Y    16h30                       Tiger shark?
#
#                                 investigator_or_source  \
# 0                                  WA Today, 6/11/2017
# 1    https://sharkincidents.com/attacks/2017/austra...
# 2                Daytona Beach News-Journal, 6/10/2017
# 3                                       C. Moore, GSAF
# 4                                  Nine News, 6/7/2017
# ..                                                 ...
# 493              Daytona Beach News-Journal, 8/28/2013
# 494                    Great Lakes Advocate, 8/28/2013
# 495                          T. Mori, KHON2, 8/18/2013
# 496                                         R. Collier
# 497                                   KHON2, 8/15/2013
#
#                            pdf  \
# 0          2017.06.11-Goff.pdf
# 1    2017.06.10.b-Flinders.pdf
# 2       2017.06.10.a-Brock.pdf
# 3     2017.06.07.R-Thomson.pdf
# 4       2017.06.04-Simpson.pdf
# ..                         ...
# 493     2013.08.25-OttoLee.pdf
# 494     2013.08.25-Breihan.pdf
# 495     2013.08.18-Napeahi.pdf
# 496     2013.08.17-Zaccaro.pdf
# 497   2013.08.14-Lutteropp.pdf
#
#                                           href_formula  \
# 0    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2    http://sharkattackfile.net/spreadsheets/pdf_di...
# 3    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4    http://sharkattackfile.net/spreadsheets/pdf_di...
# ..                                                 ...
# 493  http://sharkattackfile.net/spreadsheets/pdf_di...
# 494  http://sharkattackfile.net/spreadsheets/pdf_di...
# 495  http://sharkattackfile.net/spreadsheets/pdf_di...
# 496  http://sharkattackfile.net/spreadsheets/pdf_di...
# 497  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href case_number.1  \
# 0    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.06.11
# 1    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.06.10.b
# 2    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.06.10.a
# 3    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.06.07.R
# 4    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.06.04
# ..                                                 ...           ...
# 493  http://sharkattackfile.net/spreadsheets/pdf_di...  2013.08.25.b
# 494  http://sharkattackfile.net/spreadsheets/pdf_di...    2013.08.25
# 495  http://sharkattackfile.net/spreadsheets/pdf_di...    2013.08.18
# 496  http://sharkattackfile.net/spreadsheets/pdf_di...    2013.08.17
# 497  http://sharkattackfile.net/spreadsheets/pdf_di...    2013.08.14
#
#     case_number.2 original_order
# 0      2017.06.11         6095.0
# 1    2017.06.10.b         6094.0
# 2    2017.06.10.a         6093.0
# 3    2017.06.07.R         6092.0
# 4      2017.06.04         6091.0
# ..            ...            ...
# 493  2013.08.25.b         5600.0
# 494    2013.08.25         5599.0
# 495    2013.08.18         5598.0
# 496    2013.08.17         5597.0
# 497    2013.08.14         5596.0
#
# [498 rows x 24 columns]

# %%
df = df.astype('string')

# %%
df_provoked = df[df['type'] == 'Provoked']

# %%
df_provoked = df_provoked[['date','location','activity','name','sex_','age','injury','species_']]

# %%
df_provoked.at[41,'age'] = '35'

# %%
df_provoked['merge'] = df_provoked['date'] + '\r' + df_provoked['sex_'] + '/' + df_provoked['age'] + '/' + df_provoked['location'] + '\r' + df_provoked['activity'] + '\r' + df_provoked['injury'] + '\r' + df_provoked['species_']

# %%
df_provoked['LAT'] = np.nan

# %%
df_provoked['LON'] = np.nan

# %%
df_provoked.iloc[0]
# Out:
# date                                               2017-05-30
# location                           Awendaw, Charleston County
# activity                                     Touching a shark
# name                                        Mackenzie Higgins
# sex_                                                        F
# age                                                        20
# injury      Right hand bitten by hooked shark PROVOKED INC...
# species_                                             3' shark
# merge       2017-05-30\rF/20/Awendaw, Charleston County\rT...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 6, dtype: object

# %%
df_provoked.at[6,'LAT'] = '32.9714'

# %%
df_provoked.at[6,'LON'] = '-79.7234'

# %%
df_provoked.iloc[1]
# Out:
# date                                               2017-05-06
# location                                                Weipa
# activity                          Attempting to lasso a shark
# name                                              Josh Neille
# sex_                                                        M
# age                                                        29
# injury                         Thigh nipped PROVOKED INCIDENT
# species_                                             9' shark
# merge       2017-05-06\rM/29/Weipa\rAttempting to lasso a ...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 10, dtype: object

# %%
df_provoked.at[10,'LAT'] = '-12.6235'

# %%
df_provoked.at[10,'LON'] = '141.879'

# %%
df_provoked.iloc[2]
# Out:
# date                                               2017-02-06
# location                      Fernando de Noronha Marine Park
# activity                          Grabbing shark for a selfie
# name                                                     <NA>
# sex_                                                        F
# age                                                        35
# injury              Minor injury to finger, PROVOKED INCIDENT
# species_                                      Lemon shark pup
# merge       2017-02-06\rF/35/Fernando de Noronha Marine Pa...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 41, dtype: object

# %%
df_provoked.at[41,'LAT'] = '-3.853808'

# %%
df_provoked.at[41,'LON'] = '-32.423786'

# %%
'''
https://www.actionnewsjax.com/news/trending-now/watch-tourist-bitten-by-shark-while-trying-to-take-selfie/492702288/
'''

# %%
df_provoked.iloc[3]
# Out:
# date                                               2016-12-06
# location                                            Merimbula
# activity                                         Surf fishing
# name                                           Jesse Phillips
# sex_                                                        M
# age                                                        20
# injury      Lacerations to both hands while attempting to ...
# species_                                  Wobbegong shark, 2m
# merge       2016-12-06\rM/20/Merimbula\rSurf fishing\rLace...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 59, dtype: object

# %%
df_provoked.at[59,'LAT'] = '-36.889'

# %%
df_provoked.at[59,'LON'] = '149.910'

# %%
df_provoked.iloc[4]
# Out:
# date                                               2016-11-28
# location                                          Queenscliff
# activity                                              Fishing
# name                                            Rod McFarlane
# sex_                                                        M
# age                                                        73
# injury      Laceration to right hand by hooked & gaffed sh...
# species_                     Broadnose sevengill shark, 1.5 m
# merge       2016-11-28\rM/73/Queenscliff\rFishing\rLacerat...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 61, dtype: object

# %%
df_provoked.at[61,'LAT'] = '-38.26789000'

# %%
df_provoked.at[61,'LON'] = '144.66193000'

# %%
df_provoked.iloc[5]
# Out:
# date                                               2016-07-27
# location                          Florida Keys, Monroe County
# activity                                           Lobstering
# name                                              Warren Sapp
# sex_                                                        M
# age                                                        43
# injury           Laceration to left forearm PROVOKED INCIDENT
# species_                                      Nurse shark, 4'
# merge       2016-07-27\rM/43/Florida Keys, Monroe County\r...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 100, dtype: object

# %%
df_provoked.at[100,'LAT'] = '24.691402'
df_provoked.at[100,'LON'] = '-81.189682'

# %%
df_provoked.iloc[6]
# Out:
# date                                               2016-07-20
# location                20 k off The Spit, off the Gold Coast
# activity                                              Fishing
# name                                          Scott van Burck
# sex_                                                        M
# age                                                        31
# injury      Laceration to left calf from hooked shark PROV...
# species_                                       reef shark, 1m
# merge       2016-07-20\rM/31/20 k off The Spit, off the Go...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 105, dtype: object

# %%
df_provoked.at[105,'LAT'] = '-27.93633300'
df_provoked.at[105,'LON'] = '153.42933300'

# %%
df_provoked.iloc[7]
# Out:
# date                                               2016-07-07
# location                         Off Gloucester, Essec County
# activity                                              Fishing
# name                                            Roger Brissom
# sex_                                                        M
# age                                                        59
# injury      Fin of hooked shark injured fisherman's forear...
# species_                                        dogfish shark
# merge       2016-07-07\rM/59/Off Gloucester, Essec County\...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 114, dtype: object

# %%
df_provoked.at[114,'LAT'] = '42.62455'
df_provoked.at[114,'LON'] = '-70.662365'

# %%
df_provoked.iloc[8]
# Out:
# date                                               2016-07-04
# location                                           Palm Cove
# activity                                              Fishing
# name                                            Nathan Oliver
# sex_                                                        M
# age                                                        34
# injury      Right thigh injured by hooked pregnant female ...
# species_                                    Tawny nurse shark
# merge       2016-07-04\rM/34/Palm Cove \rFishing\rRight th...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 117, dtype: object

# %%
df_provoked.at[117,'LAT'] = '-16.747201'
df_provoked.at[117,'LON'] = '145.668544987573'

# %%
df_provoked.iloc[9]
# Out:
# date                                               2016-06-15
# location                                            Coral Bay
# activity                                         Spearfishing
# name                                                Brad Vale
# sex_                                                        M
# age                                                        19
# injury      No injury but shark punctured his wetsuit afte...
# species_                                             5' shark
# merge       2016-06-15\rM/19/Coral Bay\rSpearfishing\rNo i...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 125, dtype: object

# %%
df_provoked.at[125,'LAT'] = '-23.144722'
df_provoked.at[125,'LON'] = '113.776390'

# %%
df_provoked.iloc[10]
# Out:
# date                                               2016-05-15
# location                        Boca Raton, Palm Beach County
# activity                                      Teasing a shark
# name                                                     <NA>
# sex_                                                        F
# age                                                        23
# injury                          Arm grabbed PROVOKED INCIDENT
# species_                                      Nurse shark, 2'
# merge       2016-05-15\rF/23/Boca Raton, Palm Beach County...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 141, dtype: object

# %%
df_provoked.at[141,'LAT'] = '26.3895878'
df_provoked.at[141,'LON'] = '-80.1230772'

# %%
df_provoked.iloc[11]
# Out:
# date                                               2016-05-02
# location                                            Cormandel
# activity                                              Fishing
# name                                                     <NA>
# sex_                                                        M
# age                                                        39
# injury          Foot bitten by landed shark PROVOKED INCIDENT
# species_                              Mako shark, 1.5 m [5']
# merge       2016-05-02\rM/39/Cormandel\rFishing\rFoot bitt...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 143, dtype: object

# %%
df_provoked.at[143,'LAT'] = '-36.7611'
df_provoked.at[143,'LON'] = '175.496'

# %%
df_provoked.iloc[12]
# Out:
# date                                               2016-04-18
# location                                         Makemo Atoll
# activity                                         Spearfishing
# name                                            Teva Tokoragi
# sex_                                                        M
# age                                                        26
# injury      Severe lacerations to right forearm, hand and ...
# species_                                 Grey reef shark, 2 m
# merge       2016-04-18\rM/26/Makemo Atoll\rSpearfishing\rS...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 148, dtype: object

# %%
df_provoked.at[148,'LAT'] = '-16.6008'
df_provoked.at[148,'LON'] = '-143.7166'

# %%
df_provoked.iloc[13]
# Out:
# date                                     2016-03-26
# location                                       <NA>
# activity                                       <NA>
# name                                Henry Kreckman
# sex_                                              M
# age                                               9
# injury      Minor injury to chest PROVOKED INCIDENT
# species_                        Nurse shark, 2.5-ft
# merge                                          <NA>
# LAT                                             NaN
# LON                                             NaN
# Name: 158, dtype: object

# %%
df_provoked.at[158,'LAT'] = '25.025885'
df_provoked.at[158,'LON'] = '-78.035889'

# %%
df_provoked.iloc[14]
# Out:
# date                                               2015-09-05
# location                     Deer Creek Beach, Ventura County
# activity                                        Kayak Fishing
# name                                              Dylan Marks
# sex_                                                        M
# age                                                        29
# injury      Laceration to dorsum of foot by hooked shark  ...
# species_                                    Hammerhead shark.
# merge       2015-09-05\rM/29/Deer Creek Beach, Ventura Cou...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 225, dtype: object

# %%
df_provoked.at[225,'LAT'] = '34.0817'
df_provoked.at[225,'LON'] = '-118.9808'

# %%
df_provoked.iloc[15]
# Out:
# date                                               2015-08-10
# location                                          Cortes Bank
# activity                                         Spearfishing
# name                                           Richard Shafer
# sex_                                                        M
# age                                                        57
# injury                   Right hand bitten  PROVOKED INCIDENT
# species_                           Hammerhead shark. 6' to 7'
# merge       2015-08-10\rM/57/Cortes Bank\rSpearfishing\rRi...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 238, dtype: object

# %%
df_provoked.at[238,'LAT'] = '32.478'
df_provoked.at[238,'LON'] = '-119.215'

# %%
df_provoked.iloc[16]
# Out:
# date                                               2015-07-23
# location                           La Jolla, San Diego County
# activity                                        Kayak Fishing
# name                                            Austin Lorber
# sex_                                                        M
# age                                                        31
# injury      No injury to occupant. Kayak bitten by gaffed ...
# species_                                   Mako shark, 100-lb
# merge       2015-07-23\rM/31/La Jolla, San Diego County\rK...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 244, dtype: object

# %%
df_provoked.at[244,'LAT'] = '32.842674'
df_provoked.at[244,'LON'] = '-117.257767'

# %%
df_provoked.iloc[17]
# Out:
# date                                               2015-06-25
# location                                      Rottnest Island
# activity                                             Swimming
# name                                                  Stephen
# sex_                                                        M
# age                                                        19
# injury      Minor lacerations to forearm when he grabbed s...
# species_                                      Wobbegong shark
# merge       2015-06-25\rM/19/Rottnest Island\rSwimming\rMi...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 263, dtype: object

# %%
df_provoked.at[263,'LAT'] = '-31.9970'
df_provoked.at[263,'LON'] = '115.5402'

# %%
df_provoked.iloc[18]
# Out:
# date                                               2015-03-10
# location                                             Mazlatan
# activity                                              Fishing
# name                                      David Villegas Mora
# sex_                                                        M
# age                                                        36
# injury      Right hand bitten by hooked shark PROVOKED INC...
# species_                                                 <NA>
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 302, dtype: object

# %%
df_provoked.at[302,'LAT'] = '23.249414'
df_provoked.at[302,'LON'] = '-106.411140'

# %%
df_provoked.iloc[19]
# Out:
# date                                               2015-01-27
# location                                              Lahaina
# activity                                        Shark fishing
# name                                          Michael Pollard
# sex_                                                        M
# age                                                        20
# injury      Lacerations to calf by hooked shark PROVOKED I...
# species_                                             4' shark
# merge       2015-01-27\rM/20/Lahaina\rShark fishing\rLacer...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 310, dtype: object

# %%
df_provoked.at[310,'LAT'] = '20.878525'
df_provoked.at[310,'LON'] = '-156.683746'

# %%
df_provoked.iloc[20]
# Out:
# date                                               2014-12-28
# location                                       Paradise Beach
# activity                                              Fishing
# name                                                     <NA>
# sex_                                                        M
# age                                                       40s
# injury      Laceration to calf when he fell on shark he ha...
# species_                                          1.5 m shark
# merge       2014-12-28\rM/40s/Paradise Beach\rFishing\rLac...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 326, dtype: object

# %%
df_provoked.at[326,'LAT'] = '-37.020100'
df_provoked.at[326,'LON'] = '-144.964600'

# %%
df_provoked.iloc[21]
# Out:
# date                                               2014-12-03
# location                                           Off Motril
# activity                              Fishing for blue sharks
# name                                                     <NA>
# sex_                                                        M
# age                                                      <NA>
# injury      Glancing bite to wrist from netted shark PROVO...
# species_                                                 <NA>
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 329, dtype: object

# %%
df_provoked.at[329,'LAT'] = '36.7446588'
df_provoked.at[329,'LON'] = '-3.5166661'

# %%
df_provoked.iloc[22]
# Out:
# date                                               2014-11-20
# location                                                 <NA>
# activity                                              Fishing
# name                                     Rameshwar Ram Dhauro
# sex_                                                        M
# age                                                        39
# injury      FATAL, arm bitten by shark hauled on deck     ...
# species_                                                 <NA>
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 331, dtype: object

# %%
df_provoked.at[331,'LAT'] = '-16.583331'
df_provoked.at[331,'LON'] = '59.6166642'

# %%
df_provoked.iloc[23]
# Out:
# date                                               2014-10-29
# location                                        Wallabi Point
# activity                                              Surfing
# name                                                Ryan Hunt
# sex_                                                        M
# age                                                        20
# injury      Laceration to dorsum of left foot when he step...
# species_                                                 <NA>
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 339, dtype: object

# %%
df_provoked.at[339,'LAT'] = '-32.017'
df_provoked.at[339,'LON'] = '152.567'

# %%
df_provoked.iloc[24]
# Out:
# date                                               2014-09-02
# location     Fletcher Beach, Hutchinson Island, Martin County
# activity                                              Fishing
# name                                                     <NA>
# sex_                                                        M
# age                                                        52
# injury      Bitten twice on the leg by a shark he was atte...
# species_                                       3' to 4' shark
# merge       2014-09-02\rM/52/Fletcher Beach, Hutchinson Is...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 361, dtype: object

# %%
df_provoked.at[361,'LAT'] = '27.0673711'
df_provoked.at[361,'LON'] = '-80.3994412'

# %%
df_provoked.iloc[25]
# Out:
# date                                               2014-08-28
# location                         Assateague National Seashore
# activity                                              Fishing
# name                                           Mathew Vickers
# sex_                                                        M
# age                                                        33
# injury      Lacerations to foot by hooked shark PROVOKED I...
# species_                                                 <NA>
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 366, dtype: object

# %%
df_provoked.at[366,'LAT'] = '38.2292831'
df_provoked.at[366,'LON'] = '-75.14352'

# %%
df_provoked.iloc[26]
# Out:
# date                                               2014-08-25
# location                                    Apalachicola Bay
# activity                                   Fishing for sharks
# name                                               John Wiley
# sex_                                                        M
# age                                                      <NA>
# injury      Lacerations to forearm from hooked shark PROVO...
# species_                                    Bull shark, 4.5'
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 370, dtype: object

# %%
df_provoked.at[370,'LAT'] = '29.725767'
df_provoked.at[370,'LON'] = '-84.983246'

# %%
df_provoked.iloc[27]
# Out:
# date                                               2014-07-05
# location                  Manhattan Beach, Los Angeles County
# activity                                             Swimming
# name                                             Steve Robles
# sex_                                                        M
# age                                                      <NA>
# injury      PROVOKED INCIDENT Torso bitten by shark hooked...
# species_                                     White shark, 7'
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 393, dtype: object

# %%
df_provoked.at[393,'LAT'] = '33.881248'
df_provoked.at[393,'LON'] = '-118.407211'

# %%
df_provoked.iloc[28]
# Out:
# date                                               2014-06-17
# location                                     Horizontal Falls
# activity                                      Petting a shark
# name                                               Ric Wright
# sex_                                                        M
# age                                                      <NA>
# injury      Lacerations to right hand by captive shark PRO...
# species_                                   Lemon shark, 3.5 m
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 400, dtype: object

# %%
df_provoked.at[400,'LAT'] = '-16.376498494'
df_provoked.at[400,'LON'] = '123.954829514'

# %%
df_provoked.iloc[29]
# Out:
# date                                               2014-05-22
# location                  The Australian Shark and Ray Centre
# activity                                      Teasing a shark
# name                                                     <NA>
# sex_                                                        M
# age                                                        10
# injury      Cut to tip of finger by a captive shark PROVOK...
# species_                               Tawney nurse shark, 1m
# merge       2014-05-22\rM/10/The Australian Shark and Ray ...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 411, dtype: object

# %%
df_provoked.at[411,'LAT'] = '-31.840233'
df_provoked.at[411,'LON'] = '145.612793'

# %%
df_provoked.iloc[30]
# Out:
# date                                               2014-04-12
# location                                          Port Alfred
# activity                                              Fishing
# name                                         Lionel McDougall
# sex_                                                        M
# age                                                      <NA>
# injury      Lacerations to leg & hand by hooked shark PROV...
# species_                                Raggedtooth shark, 2m
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 425, dtype: object

# %%
df_provoked.at[425,'LAT'] = '-33.600395'
df_provoked.at[425,'LON'] = '26.891699'

# %%
df_provoked.iloc[31]
# Out:
# date                          2014-02-07
# location                            <NA>
# activity                         Fishing
# name                        Simon Torres
# sex_                                   M
# age                                 <NA>
# injury      Possibly a PROVOKED INCIDENT
# species_                            <NA>
# merge                               <NA>
# LAT                                  NaN
# LON                                  NaN
# Name: 442, dtype: object

# %%
df_provoked.at[442,'LAT'] = '10.536421'
df_provoked.at[442,'LON'] = '-61.311951'

# %%
df_provoked.iloc[32]
# Out:
# date                                               2014-01-26
# location                                          Umina Beach
# activity                                              Fishing
# name                                         Richard O'Connor
# sex_                                                        M
# age                                                      <NA>
# injury      Lacerations to ring and pinky fingers of his l...
# species_                                             1m shark
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 444, dtype: object

# %%
df_provoked.at[444,'LAT'] = '-33.525501'
df_provoked.at[444,'LON'] = '151.319595'

# %%
df_provoked.iloc[33]
# Out:
# date                                               2013-11-10
# location                                   Off Cape Eleuthera
# activity                                        Shark fishing
# name                                                     <NA>
# sex_                                                        M
# age                                                        77
# injury      Injuries to arm & leg by hooked shark   PROVOK...
# species_                                                 <NA>
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 460, dtype: object

# %%
df_provoked.at[460,'LAT'] = '25.28389'
df_provoked.at[460,'LON'] = '-76.33083'

# %%
df_provoked.iloc[34]
# Out:
# date                           2013-09-29
# location                           Ashdod
# activity                           Diving
# name                             Erez Lev
# sex_                                    M
# age                                    27
# injury      Hand bitten PROVOKED INCIDENT
# species_                             <NA>
# merge                                <NA>
# LAT                                   NaN
# LON                                   NaN
# Name: 476, dtype: object

# %%
df_provoked.at[476,'LAT'] = '31.801447'
df_provoked.at[476,'LON'] = '34.643497'

# %%
df_provoked.iloc[35]
# Out:
# date                                               2013-09-07
# location                    New Smyrna Beach,  Volusia County
# activity                                              Surfing
# name                                              John Graham
# sex_                                                        M
# age                                                        43
# injury      Foot bitten when he accidentally jumped onto t...
# species_                                             3' shark
# merge       2013-09-07\rM/43/New Smyrna Beach,  Volusia Co...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 483, dtype: object

# %%
df_provoked.at[483,'LAT'] = '29.036013'
df_provoked.at[483,'LON'] = '-80.964966'

# %%
df_provoked.iloc[36]
# Out:
# date                                           2013-09-01
# location                                Key West Aquarium
# activity                                             <NA>
# name                                                 <NA>
# sex_                                                    M
# age                                                     3
# injury      Arm bitten by captive shark PROVOKED INCIDENT
# species_                                      Nurse shark
# merge                                                <NA>
# LAT                                                   NaN
# LON                                                   NaN
# Name: 486, dtype: object

# %%
df_provoked.at[486,'LAT'] = '24.555059'
df_provoked.at[486,'LON'] = '-81.779984'

# %%
df_provoked.iloc[37]
# Out:
# date                                               2013-08-26
# location                                                 <NA>
# activity                          Longline fishing for sharks
# name                                              Ramon Arufe
# sex_                                                        M
# age                                                        50
# injury      Laceration to right arm from hooked shark  PRO...
# species_                                       Mako shark, 5'
# merge                                                    <NA>
# LAT                                                       NaN
# LON                                                       NaN
# Name: 492, dtype: object

# %%
df_provoked.at[492,'LAT'] = '43.37172'
df_provoked.at[492,'LON'] = '-1.77382'

# %%
df_provoked['LAT'].astype('float')

# %%
df_provoked['LON'].astype('float')
# Out:
# 6      -79.723400
# 10     141.879000
# 41     -32.423786
# 59     149.910000
# 61     144.661930
# 100    -81.189682
# 105    153.429333
# 114    -70.662365
# 117    145.668545
# 125    113.776390
# 141    -80.123077
# 143    175.496000
# 148   -143.716600
# 158    -78.035889
# 225   -118.980800
# 238   -119.215000
# 244   -117.257767
# 263    115.540200
# 302   -106.411140
# 310   -156.683746
# 326   -144.964600
# 329     -3.516666
# 331     59.616664
# 339    152.567000
# 361    -80.399441
# 366    -75.143520
# 370    -84.983246
# 393   -118.407211
# 400    123.954830
# 411    145.612793
# 425     26.891699
# 442    -61.311951
# 444    151.319595
# 460    -76.330830
# 476     34.643497
# 483    -80.964966
# 486    -81.779984
# 492     -1.773820
# 0      -79.723400
# 1      141.879000
# 3      149.910000
# Name: LON, dtype: float64

# %%
world_map = folium.Map()
incidents = plugins.MarkerCluster().add_to(world_map)

# %%
for lat, lng, label, in zip(df_provoked.LAT, df_provoked.LON, df_provoked['merge']):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28fd56b090214c4bdb75790316b5bfcf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28fd56b090214c4bdb75790316b5bfcf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28fd56b090214c4bdb75790316b5bfcf = L.map(
#                 &quot;map_28fd56b090214c4bdb75790316b5bfcf&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53200ab3706d240ea68a5a841bd5b439 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_28fd56b090214c4bdb75790316b5bfcf);
#
#
#             var marker_cluster_642c01031aaf0f13e5c4469e4af248ef = L.markerClusterGroup(
#                 {}
#             );
#             map_28fd56b090214c4bdb75790316b5bfcf.addLayer(marker_cluster_642c01031aaf0f13e5c4469e4af248ef);
#
#
#             var marker_0e90dc1df28dee3f087080fee94c2309 = L.marker(
#                 [32.9714, -79.7234],
#                 {}
#             ).addTo(marker_cluster_642c01031aaf0f13e5c4469e4af248ef);
#
#
#         var popup_620a75e11650294c71808eae6a7c2075 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b7971b165a5bcc3dc91eb22096360b47 = $(`&lt;div id=&quot;html_b7971b165a5bcc3dc91eb22096360b47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-05-30
# F/20/Awendaw, Charleston County
# Touching a shark
# Right hand bitten by hooked shark PROVOKED INCIDENT
# 3&#x27; shark&lt;/div&gt;`)[0];
#             popup_620a75e11650294c71808eae6a7c2075.setContent(html_b7971b165a5bcc3dc91eb22096360b47);
#
#
#         marker_0e90dc1df28dee3f087080fee94c2309.bindPopup(popup_620a75e11650294c71808eae6a7c2075)
#         ;
#
#
#
#
#             var marker_d7d8784b232d3b0bc3ce354ce94ba919 = L.marker(
#                 [-12.6235, 141.879],
#                 {}
#             ).addTo(marker_cluster_642c01031aaf0f13e5c4469e4af248ef);
#
#
#         var popup_8f6e7dd2f29278f986f8e2c3b40e2e89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e8eb22052e922e55de56557fb7e27557 = $(`&lt;div id=&quot;html_e8eb22052e922e55de56557fb7e27557&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-05-06
# M/29/Weipa
# Attempting to lasso a shark
# Thigh nipped PROVOKED INCIDENT
# 9&#x27; shark&lt;/div&gt;`)[0];
#             popup_8f6e7dd2f29278f986f8e2c3b40e2e89.setContent(html_e8eb22052e922e55de56557fb7e27557);
#
#
#         marker_d7d8784b232d3b0bc3ce354ce94ba919.bindPopup(popup_8f6e7dd2f29278f986f8e2c3b40e2e89)
#         ;
#
#
#
#
#             var marker_eefb55c71d69d6e701de3b8e55be64eb = L.marker(
#                 [-3.853808, -32.423786],
#                 {}
#             ).addTo(marker_cluster_642c01031aaf0f13e5c4469e4af248ef);
#
#
#         var popup_706085605ee9ce4fc6b2468d7d1321b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bb86a4f6430de7ecac13d95891b6b53b = $(`&lt;div id=&quot;html_bb86a4f6430de7ecac13d95891b6b53b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-02-06
# F/35/Fernando de Noronha Marine Park
# Grabbing shark for a selfie
# Minor injury to finger, PROVOKED INCIDENT
# Lemon shark pup&lt;/div&gt;`)[0];
#             popup_706085605ee9ce4fc6b2468d7d1321b2.setContent(html_bb86a4f6430de7ecac13d95891b6b53b);
#
#
#         marker_eefb55c71d69d6e701de3b8e55be64eb.bindPopup(popup_706085605ee9ce4fc6b2468d7d1321b2)
#         ;
#
#
#
#
#             var marker_f7f86af6a6dea9c8a95dda3d35801359 = L.marker(
#                 [-36.889, 149.91],
#                 {}
#             ).addTo(marker_cluster_642c01031aaf0f13e5c4469e4af248ef);
#
#
#         var popup_537596ebd6c2f4750ce3804abbd65590 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_06b309f45687378241389801ca569bcc = $(`&lt;div id=&quot;html_06b309f45687378241389801ca569bcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2016-12-06
# M/20/Merimbula
# Surf fishing
# Lacerations to both hands while attempting to land a hooked shark PROVOKED INCIDENT
# Wobbegong shark, 2m&lt;/div&gt;`)[0];
#             popup_537596ebd6c2f4750ce3804abbd65590.setContent(html_06b309f45687378241389801ca569bcc);
#
#
#         marker_f7f86af6a6dea9c8a95dda3d35801359.bindPopup(popup_537596ebd6c2f4750ce3804abbd65590)
#         ;
#
#
#
#
#             var marker_08

# %%
world_map.save('provokedsharkattacks.html')
