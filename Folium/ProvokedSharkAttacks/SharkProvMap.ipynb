# %%
import pandas as pd

# %%
import numpy as np

# %%
import folium

print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
from folium import plugins

# %%
df = pd.read_csv('cleaned_sharkdata2.csv')

# %%
df.fillna('Unknown', inplace=True)

# %%
df = df.astype('string')

# %%
df_provoked = df[df['type'] == 'Provoked']

# %%
df_provoked = df_provoked[['date','location','activity','name','sex_','age','injury','species_']]

# %%
df_provoked.at[41,'age'] = '35'

# %%
df_provoked['merge'] = df_provoked['date'] + ' / ' + df_provoked['sex_'] + ' / ' + df_provoked['age'] + ' / ' + df_provoked['location'] + ' / ' + df_provoked['activity'] + ' / ' + df_provoked['injury'] + ' / ' + df_provoked['species_']

# %%
df_provoked['LAT'] = np.nan

# %%
df_provoked['LON'] = np.nan

# %%
df_provoked.iloc[0]
# Out:
# date                                               2017-05-30
# location                           Awendaw, Charleston County
# activity                                     Touching a shark
# name                                        Mackenzie Higgins
# sex_                                                        F
# age                                                        20
# injury      Right hand bitten by hooked shark PROVOKED INC...
# species_                                             3' shark
# merge       2017-05-30 / F / 20 / Awendaw, Charleston Coun...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 6, dtype: object

# %%
df_provoked.at[6,'LAT'] = '32.9714'

# %%
df_provoked.at[6,'LON'] = '-79.7234'

# %%
df_provoked.iloc[1]
# Out:
# date                                               2017-05-06
# location                                                Weipa
# activity                          Attempting to lasso a shark
# name                                              Josh Neille
# sex_                                                        M
# age                                                        29
# injury                         Thigh nipped PROVOKED INCIDENT
# species_                                             9' shark
# merge       2017-05-06 / M / 29 / Weipa / Attempting to la...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 10, dtype: object

# %%
df_provoked.at[10,'LAT'] = '-12.6235'

# %%
df_provoked.at[10,'LON'] = '141.879'

# %%
df_provoked.iloc[2]
# Out:
# date                                               2017-02-06
# location                      Fernando de Noronha Marine Park
# activity                          Grabbing shark for a selfie
# name                                                  Unknown
# sex_                                                        F
# age                                                        35
# injury              Minor injury to finger, PROVOKED INCIDENT
# species_                                      Lemon shark pup
# merge       2017-02-06 / F / 35 / Fernando de Noronha Mari...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 41, dtype: object

# %%
df_provoked.at[41,'LAT'] = '-3.853808'

# %%
df_provoked.at[41,'LON'] = '-32.423786'

# %%
'''
https://www.actionnewsjax.com/news/trending-now/watch-tourist-bitten-by-shark-while-trying-to-take-selfie/492702288/
'''
# Out:
# '\nhttps://www.actionnewsjax.com/news/trending-now/watch-tourist-bitten-by-shark-while-trying-to-take-selfie/492702288/\n'

# %%
df_provoked.iloc[3]
# Out:
# date                                               2016-12-06
# location                                            Merimbula
# activity                                         Surf fishing
# name                                           Jesse Phillips
# sex_                                                        M
# age                                                        20
# injury      Lacerations to both hands while attempting to ...
# species_                                  Wobbegong shark, 2m
# merge       2016-12-06 / M / 20 / Merimbula / Surf fishing...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 59, dtype: object

# %%
df_provoked.at[59,'LAT'] = '-36.889'

# %%
df_provoked.at[59,'LON'] = '149.910'

# %%
df_provoked.iloc[4]
# Out:
# date                                               2016-11-28
# location                                          Queenscliff
# activity                                              Fishing
# name                                            Rod McFarlane
# sex_                                                        M
# age                                                        73
# injury      Laceration to right hand by hooked & gaffed sh...
# species_                     Broadnose sevengill shark, 1.5 m
# merge       2016-11-28 / M / 73 / Queenscliff / Fishing / ...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 61, dtype: object

# %%
df_provoked.at[61,'LAT'] = '-38.26789000'

# %%
df_provoked.at[61,'LON'] = '144.66193000'

# %%
df_provoked.iloc[5]
# Out:
# date                                               2016-07-27
# location                          Florida Keys, Monroe County
# activity                                           Lobstering
# name                                              Warren Sapp
# sex_                                                        M
# age                                                        43
# injury           Laceration to left forearm PROVOKED INCIDENT
# species_                                      Nurse shark, 4'
# merge       2016-07-27 / M / 43 / Florida Keys, Monroe Cou...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 100, dtype: object

# %%
df_provoked.at[100,'LAT'] = '24.691402'
df_provoked.at[100,'LON'] = '-81.189682'

# %%
df_provoked.iloc[6]
# Out:
# date                                               2016-07-20
# location                20 k off The Spit, off the Gold Coast
# activity                                              Fishing
# name                                          Scott van Burck
# sex_                                                        M
# age                                                        31
# injury      Laceration to left calf from hooked shark PROV...
# species_                                       reef shark, 1m
# merge       2016-07-20 / M / 31 / 20 k off The Spit, off t...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 105, dtype: object

# %%
df_provoked.at[105,'LAT'] = '-27.93633300'
df_provoked.at[105,'LON'] = '153.42933300'

# %%
df_provoked.iloc[7]
# Out:
# date                                               2016-07-07
# location                         Off Gloucester, Essec County
# activity                                              Fishing
# name                                            Roger Brissom
# sex_                                                        M
# age                                                        59
# injury      Fin of hooked shark injured fisherman's forear...
# species_                                        dogfish shark
# merge       2016-07-07 / M / 59 / Off Gloucester, Essec Co...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 114, dtype: object

# %%
df_provoked.at[114,'LAT'] = '42.62455'
df_provoked.at[114,'LON'] = '-70.662365'

# %%
df_provoked.iloc[8]
# Out:
# date                                               2016-07-04
# location                                           Palm Cove
# activity                                              Fishing
# name                                            Nathan Oliver
# sex_                                                        M
# age                                                        34
# injury      Right thigh injured by hooked pregnant female ...
# species_                                    Tawny nurse shark
# merge       2016-07-04 / M / 34 / Palm Cove  / Fishing / R...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 117, dtype: object

# %%
df_provoked.at[117,'LAT'] = '-16.747201'
df_provoked.at[117,'LON'] = '145.668544987573'

# %%
df_provoked.iloc[9]
# Out:
# date                                               2016-06-15
# location                                            Coral Bay
# activity                                         Spearfishing
# name                                                Brad Vale
# sex_                                                        M
# age                                                        19
# injury      No injury but shark punctured his wetsuit afte...
# species_                                             5' shark
# merge       2016-06-15 / M / 19 / Coral Bay / Spearfishing...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 125, dtype: object

# %%
df_provoked.at[125,'LAT'] = '-23.144722'
df_provoked.at[125,'LON'] = '113.776390'

# %%
df_provoked.iloc[10]
# Out:
# date                                               2016-05-15
# location                        Boca Raton, Palm Beach County
# activity                                      Teasing a shark
# name                                                  Unknown
# sex_                                                        F
# age                                                        23
# injury                          Arm grabbed PROVOKED INCIDENT
# species_                                      Nurse shark, 2'
# merge       2016-05-15 / F / 23 / Boca Raton, Palm Beach C...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 141, dtype: object

# %%
df_provoked.at[141,'LAT'] = '26.3895878'
df_provoked.at[141,'LON'] = '-80.1230772'

# %%
df_provoked.iloc[11]
# Out:
# date                                               2016-05-02
# location                                            Cormandel
# activity                                              Fishing
# name                                                  Unknown
# sex_                                                        M
# age                                                        39
# injury          Foot bitten by landed shark PROVOKED INCIDENT
# species_                              Mako shark, 1.5 m [5']
# merge       2016-05-02 / M / 39 / Cormandel / Fishing / Fo...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 143, dtype: object

# %%
df_provoked.at[143,'LAT'] = '-36.7611'
df_provoked.at[143,'LON'] = '175.496'

# %%
df_provoked.iloc[12]
# Out:
# date                                               2016-04-18
# location                                         Makemo Atoll
# activity                                         Spearfishing
# name                                            Teva Tokoragi
# sex_                                                        M
# age                                                        26
# injury      Severe lacerations to right forearm, hand and ...
# species_                                 Grey reef shark, 2 m
# merge       2016-04-18 / M / 26 / Makemo Atoll / Spearfish...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 148, dtype: object

# %%
df_provoked.at[148,'LAT'] = '-16.6008'
df_provoked.at[148,'LON'] = '-143.7166'

# %%
df_provoked.iloc[13]
# Out:
# date                                               2016-03-26
# location                                              Unknown
# activity                                              Unknown
# name                                          Henry Kreckman
# sex_                                                        M
# age                                                         9
# injury                Minor injury to chest PROVOKED INCIDENT
# species_                                  Nurse shark, 2.5-ft
# merge       2016-03-26 / M / 9 / Unknown / Unknown / Minor...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 158, dtype: object

# %%
df_provoked.at[158,'LAT'] = '25.025885'
df_provoked.at[158,'LON'] = '-78.035889'

# %%
df_provoked.iloc[14]
# Out:
# date                                               2015-09-05
# location                     Deer Creek Beach, Ventura County
# activity                                        Kayak Fishing
# name                                              Dylan Marks
# sex_                                                        M
# age                                                        29
# injury      Laceration to dorsum of foot by hooked shark  ...
# species_                                    Hammerhead shark.
# merge       2015-09-05 / M / 29 / Deer Creek Beach, Ventur...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 225, dtype: object

# %%
df_provoked.at[225,'LAT'] = '34.0817'
df_provoked.at[225,'LON'] = '-118.9808'

# %%
df_provoked.iloc[15]
# Out:
# date                                               2015-08-10
# location                                          Cortes Bank
# activity                                         Spearfishing
# name                                           Richard Shafer
# sex_                                                        M
# age                                                        57
# injury                   Right hand bitten  PROVOKED INCIDENT
# species_                           Hammerhead shark. 6' to 7'
# merge       2015-08-10 / M / 57 / Cortes Bank / Spearfishi...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 238, dtype: object

# %%
df_provoked.at[238,'LAT'] = '32.478'
df_provoked.at[238,'LON'] = '-119.215'

# %%
df_provoked.iloc[16]
# Out:
# date                                               2015-07-23
# location                           La Jolla, San Diego County
# activity                                        Kayak Fishing
# name                                            Austin Lorber
# sex_                                                        M
# age                                                        31
# injury      No injury to occupant. Kayak bitten by gaffed ...
# species_                                   Mako shark, 100-lb
# merge       2015-07-23 / M / 31 / La Jolla, San Diego Coun...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 244, dtype: object

# %%
df_provoked.at[244,'LAT'] = '32.842674'
df_provoked.at[244,'LON'] = '-117.257767'

# %%
df_provoked.iloc[17]
# Out:
# date                                               2015-06-25
# location                                      Rottnest Island
# activity                                             Swimming
# name                                                  Stephen
# sex_                                                        M
# age                                                        19
# injury      Minor lacerations to forearm when he grabbed s...
# species_                                      Wobbegong shark
# merge       2015-06-25 / M / 19 / Rottnest Island / Swimmi...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 263, dtype: object

# %%
df_provoked.at[263,'LAT'] = '-31.9970'
df_provoked.at[263,'LON'] = '115.5402'

# %%
df_provoked.iloc[18]
# Out:
# date                                               2015-03-10
# location                                             Mazlatan
# activity                                              Fishing
# name                                      David Villegas Mora
# sex_                                                        M
# age                                                        36
# injury      Right hand bitten by hooked shark PROVOKED INC...
# species_                                              Unknown
# merge       2015-03-10 / M / 36 / Mazlatan / Fishing / Rig...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 302, dtype: object

# %%
df_provoked.at[302,'LAT'] = '23.249414'
df_provoked.at[302,'LON'] = '-106.411140'

# %%
df_provoked.iloc[19]
# Out:
# date                                               2015-01-27
# location                                              Lahaina
# activity                                        Shark fishing
# name                                          Michael Pollard
# sex_                                                        M
# age                                                        20
# injury      Lacerations to calf by hooked shark PROVOKED I...
# species_                                             4' shark
# merge       2015-01-27 / M / 20 / Lahaina / Shark fishing ...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 310, dtype: object

# %%
df_provoked.at[310,'LAT'] = '20.878525'
df_provoked.at[310,'LON'] = '-156.683746'

# %%
df_provoked.iloc[20]
# Out:
# date                                               2014-12-28
# location                                       Paradise Beach
# activity                                              Fishing
# name                                                  Unknown
# sex_                                                        M
# age                                                       40s
# injury      Laceration to calf when he fell on shark he ha...
# species_                                          1.5 m shark
# merge       2014-12-28 / M / 40s / Paradise Beach / Fishin...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 326, dtype: object

# %%
df_provoked.at[326,'LAT'] = '-37.020100'
df_provoked.at[326,'LON'] = '-144.964600'

# %%
df_provoked.iloc[21]
# Out:
# date                                               2014-12-03
# location                                           Off Motril
# activity                              Fishing for blue sharks
# name                                                  Unknown
# sex_                                                        M
# age                                                   Unknown
# injury      Glancing bite to wrist from netted shark PROVO...
# species_                                              Unknown
# merge       2014-12-03 / M / Unknown / Off Motril / Fishin...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 329, dtype: object

# %%
df_provoked.at[329,'LAT'] = '36.7446588'
df_provoked.at[329,'LON'] = '-3.5166661'

# %%
df_provoked.iloc[22]
# Out:
# date                                               2014-11-20
# location                                              Unknown
# activity                                              Fishing
# name                                     Rameshwar Ram Dhauro
# sex_                                                        M
# age                                                        39
# injury      FATAL, arm bitten by shark hauled on deck     ...
# species_                                              Unknown
# merge       2014-11-20 / M / 39 / Unknown / Fishing / FATA...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 331, dtype: object

# %%
df_provoked.at[331,'LAT'] = '-16.583331'
df_provoked.at[331,'LON'] = '59.6166642'

# %%
df_provoked.iloc[23]
# Out:
# date                                               2014-10-29
# location                                        Wallabi Point
# activity                                              Surfing
# name                                                Ryan Hunt
# sex_                                                        M
# age                                                        20
# injury      Laceration to dorsum of left foot when he step...
# species_                                              Unknown
# merge       2014-10-29 / M / 20 / Wallabi Point / Surfing ...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 339, dtype: object

# %%
df_provoked.at[339,'LAT'] = '-32.017'
df_provoked.at[339,'LON'] = '152.567'

# %%
df_provoked.iloc[24]
# Out:
# date                                               2014-09-02
# location     Fletcher Beach, Hutchinson Island, Martin County
# activity                                              Fishing
# name                                                  Unknown
# sex_                                                        M
# age                                                        52
# injury      Bitten twice on the leg by a shark he was atte...
# species_                                       3' to 4' shark
# merge       2014-09-02 / M / 52 / Fletcher Beach, Hutchins...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 361, dtype: object

# %%
df_provoked.at[361,'LAT'] = '27.0673711'
df_provoked.at[361,'LON'] = '-80.3994412'

# %%
df_provoked.iloc[25]
# Out:
# date                                               2014-08-28
# location                         Assateague National Seashore
# activity                                              Fishing
# name                                           Mathew Vickers
# sex_                                                        M
# age                                                        33
# injury      Lacerations to foot by hooked shark PROVOKED I...
# species_                                              Unknown
# merge       2014-08-28 / M / 33 / Assateague National Seas...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 366, dtype: object

# %%
df_provoked.at[366,'LAT'] = '38.2292831'
df_provoked.at[366,'LON'] = '-75.14352'

# %%
df_provoked.iloc[26]
# Out:
# date                                               2014-08-25
# location                                    Apalachicola Bay
# activity                                   Fishing for sharks
# name                                               John Wiley
# sex_                                                        M
# age                                                   Unknown
# injury      Lacerations to forearm from hooked shark PROVO...
# species_                                    Bull shark, 4.5'
# merge       2014-08-25 / M / Unknown / Apalachicola Bay  /...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 370, dtype: object

# %%
df_provoked.at[370,'LAT'] = '29.725767'
df_provoked.at[370,'LON'] = '-84.983246'

# %%
df_provoked.iloc[27]
# Out:
# date                                               2014-07-05
# location                  Manhattan Beach, Los Angeles County
# activity                                             Swimming
# name                                             Steve Robles
# sex_                                                        M
# age                                                   Unknown
# injury      PROVOKED INCIDENT Torso bitten by shark hooked...
# species_                                     White shark, 7'
# merge       2014-07-05 / M / Unknown / Manhattan Beach, Lo...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 393, dtype: object

# %%
df_provoked.at[393,'LAT'] = '33.881248'
df_provoked.at[393,'LON'] = '-118.407211'

# %%
df_provoked.iloc[28]
# Out:
# date                                               2014-06-17
# location                                     Horizontal Falls
# activity                                      Petting a shark
# name                                               Ric Wright
# sex_                                                        M
# age                                                   Unknown
# injury      Lacerations to right hand by captive shark PRO...
# species_                                   Lemon shark, 3.5 m
# merge       2014-06-17 / M / Unknown / Horizontal Falls / ...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 400, dtype: object

# %%
df_provoked.at[400,'LAT'] = '-16.376498494'
df_provoked.at[400,'LON'] = '123.954829514'

# %%
df_provoked.iloc[29]
# Out:
# date                                               2014-05-22
# location                  The Australian Shark and Ray Centre
# activity                                      Teasing a shark
# name                                                  Unknown
# sex_                                                        M
# age                                                        10
# injury      Cut to tip of finger by a captive shark PROVOK...
# species_                               Tawney nurse shark, 1m
# merge       2014-05-22 / M / 10 / The Australian Shark and...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 411, dtype: object

# %%
df_provoked.at[411,'LAT'] = '-31.840233'
df_provoked.at[411,'LON'] = '145.612793'

# %%
df_provoked.iloc[30]
# Out:
# date                                               2014-04-12
# location                                          Port Alfred
# activity                                              Fishing
# name                                         Lionel McDougall
# sex_                                                        M
# age                                                   Unknown
# injury      Lacerations to leg & hand by hooked shark PROV...
# species_                                Raggedtooth shark, 2m
# merge       2014-04-12 / M / Unknown / Port Alfred / Fishi...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 425, dtype: object

# %%
df_provoked.at[425,'LAT'] = '-33.600395'
df_provoked.at[425,'LON'] = '26.891699'

# %%
df_provoked.iloc[31]
# Out:
# date                                               2014-02-07
# location                                              Unknown
# activity                                              Fishing
# name                                             Simon Torres
# sex_                                                        M
# age                                                   Unknown
# injury                           Possibly a PROVOKED INCIDENT
# species_                                              Unknown
# merge       2014-02-07 / M / Unknown / Unknown / Fishing /...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 442, dtype: object

# %%
df_provoked.at[442,'LAT'] = '10.536421'
df_provoked.at[442,'LON'] = '-61.311951'

# %%
df_provoked.iloc[32]
# Out:
# date                                               2014-01-26
# location                                          Umina Beach
# activity                                              Fishing
# name                                         Richard O'Connor
# sex_                                                        M
# age                                                   Unknown
# injury      Lacerations to ring and pinky fingers of his l...
# species_                                             1m shark
# merge       2014-01-26 / M / Unknown / Umina Beach / Fishi...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 444, dtype: object

# %%
df_provoked.at[444,'LAT'] = '-33.525501'
df_provoked.at[444,'LON'] = '151.319595'

# %%
df_provoked.iloc[33]
# Out:
# date                                               2013-11-10
# location                                   Off Cape Eleuthera
# activity                                        Shark fishing
# name                                                  Unknown
# sex_                                                        M
# age                                                        77
# injury      Injuries to arm & leg by hooked shark   PROVOK...
# species_                                              Unknown
# merge       2013-11-10 / M / 77 / Off Cape Eleuthera / Sha...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 460, dtype: object

# %%
df_provoked.at[460,'LAT'] = '25.28389'
df_provoked.at[460,'LON'] = '-76.33083'

# %%
df_provoked.iloc[34]
# Out:
# date                                               2013-09-29
# location                                               Ashdod
# activity                                               Diving
# name                                                 Erez Lev
# sex_                                                        M
# age                                                        27
# injury                          Hand bitten PROVOKED INCIDENT
# species_                                              Unknown
# merge       2013-09-29 / M / 27 / Ashdod / Diving / Hand b...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 476, dtype: object

# %%
df_provoked.at[476,'LAT'] = '31.801447'
df_provoked.at[476,'LON'] = '34.643497'

# %%
df_provoked.iloc[35]
# Out:
# date                                               2013-09-07
# location                    New Smyrna Beach,  Volusia County
# activity                                              Surfing
# name                                              John Graham
# sex_                                                        M
# age                                                        43
# injury      Foot bitten when he accidentally jumped onto t...
# species_                                             3' shark
# merge       2013-09-07 / M / 43 / New Smyrna Beach,  Volus...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 483, dtype: object

# %%
df_provoked.at[483,'LAT'] = '29.036013'
df_provoked.at[483,'LON'] = '-80.964966'

# %%
df_provoked.iloc[36]
# Out:
# date                                               2013-09-01
# location                                    Key West Aquarium
# activity                                              Unknown
# name                                                  Unknown
# sex_                                                        M
# age                                                         3
# injury          Arm bitten by captive shark PROVOKED INCIDENT
# species_                                          Nurse shark
# merge       2013-09-01 / M / 3 / Key West Aquarium / Unkno...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 486, dtype: object

# %%
df_provoked.at[486,'LAT'] = '24.555059'
df_provoked.at[486,'LON'] = '-81.779984'

# %%
df_provoked.iloc[37]
# Out:
# date                                               2013-08-26
# location                                              Unknown
# activity                          Longline fishing for sharks
# name                                              Ramon Arufe
# sex_                                                        M
# age                                                        50
# injury      Laceration to right arm from hooked shark  PRO...
# species_                                       Mako shark, 5'
# merge       2013-08-26 / M / 50 / Unknown / Longline fishi...
# LAT                                                       NaN
# LON                                                       NaN
# Name: 492, dtype: object

# %%
df_provoked.at[492,'LAT'] = '43.37172'
df_provoked.at[492,'LON'] = '-1.77382'

# %%
df_provoked['LAT'].astype('float')
# Out:
# 6      32.971400
# 10    -12.623500
# 41     -3.853808
# 59    -36.889000
# 61    -38.267890
# 100    24.691402
# 105   -27.936333
# 114    42.624550
# 117   -16.747201
# 125   -23.144722
# 141    26.389588
# 143   -36.761100
# 148   -16.600800
# 158    25.025885
# 225    34.081700
# 238    32.478000
# 244    32.842674
# 263   -31.997000
# 302    23.249414
# 310    20.878525
# 326   -37.020100
# 329    36.744659
# 331   -16.583331
# 339   -32.017000
# 361    27.067371
# 366    38.229283
# 370    29.725767
# 393    33.881248
# 400   -16.376498
# 411   -31.840233
# 425   -33.600395
# 442    10.536421
# 444   -33.525501
# 460    25.283890
# 476    31.801447
# 483    29.036013
# 486    24.555059
# 492    43.371720
# Name: LAT, dtype: float64

# %%
df_provoked['LON'].astype('float')
# Out:
# 6      -79.723400
# 10     141.879000
# 41     -32.423786
# 59     149.910000
# 61     144.661930
# 100    -81.189682
# 105    153.429333
# 114    -70.662365
# 117    145.668545
# 125    113.776390
# 141    -80.123077
# 143    175.496000
# 148   -143.716600
# 158    -78.035889
# 225   -118.980800
# 238   -119.215000
# 244   -117.257767
# 263    115.540200
# 302   -106.411140
# 310   -156.683746
# 326   -144.964600
# 329     -3.516666
# 331     59.616664
# 339    152.567000
# 361    -80.399441
# 366    -75.143520
# 370    -84.983246
# 393   -118.407211
# 400    123.954830
# 411    145.612793
# 425     26.891699
# 442    -61.311951
# 444    151.319595
# 460    -76.330830
# 476     34.643497
# 483    -80.964966
# 486    -81.779984
# 492     -1.773820
# Name: LON, dtype: float64

# %%
df_provoked.to_csv('CSVProvokedSharkAttacks.csv')

# %%
world_map = folium.Map(location=[25, -80], zoom_start=2, max_bounds=True)
incidents = plugins.MarkerCluster().add_to(world_map)

# %%
for lat, lng, label, in zip(df_provoked.LAT, df_provoked.LON, df_provoked['merge']):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
world_map.save('provokedsharkattacks.html')
